# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        os.path.join(dirname, filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Installing and importing libraries

# %%
#pip install dicomsdl

# %%
import dicomsdl as dicoml
import cv2
import pydicom

from joblib import Parallel, delayed
import glob
import time
import numpy as np
import os
from matplotlib import pyplot as plt
from tqdm import tqdm

# %% [markdown]
# creating directory to save png images and making a file list

# %%
image_dir_dicomsdl = '/kaggle/working/png_file_dic/'

os.makedirs(image_dir_dicomsdl, exist_ok=True)

IMAGES_TO_PROCESS = 500

# %%
train_images = glob.glob("/kaggle/input/rsna-breast-cancer-detection/train_images/*/*.dcm")
len(train_images)
# Out:
# 54706

# %%
train_images[0]
# Out:
# '/kaggle/input/rsna-breast-cancer-detection/train_images/10706/763186195.dcm'

# %% [markdown]
# processing files into png format

# %%
def process(f, size=512, save_folder=None, extension="png"):
    
    patient = f.split('/')[-2]
    image_name = f.split('/')[-1][:-4]
    
    dicom = dicoml.open(f)
    img = dicom.pixelData()

    img = (img - img.min()) / (img.max() - img.min())

    if dicom.getPixelDataInfo()['PhotometricInterpretation'] == "MONOCHROME1":
        img = 1 - img

    image = (img * 255).astype(np.uint8)
    
    img = cv2.resize(image, (size, size))

    file_name = f'{save_folder}' + f"{patient}_{image_name}.{extension}"

    cv2.imwrite(file_name, img)

# %%
Parallel(n_jobs=4)(
    delayed(process)(f, size = 512, save_folder = image_dir_dicomsdl)
    for f in train_images[:IMAGES_TO_PROCESS]
)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# for f in tqdm(train_images):
#     process(f, size = 512, save_folder = image_dir_dicomsdl)

# %% [markdown]
# listing files created

# %%
import glob

# current directory
path = image_dir_dicomsdl

# list all files in the directory
files = glob.glob(path + '/*')

for file in files:
    print(file)
    print()
# Out:
# /kaggle/working/png_file_dic/8785_1050149859.png
#
# /kaggle/working/png_file_dic/32621_721584760.png
#
# /kaggle/working/png_file_dic/63210_557464063.png
#
# /kaggle/working/png_file_dic/7397_1708692259.png
#
# /kaggle/working/png_file_dic/47184_1264064360.png
#
# /kaggle/working/png_file_dic/13337_576175675.png
#
# /kaggle/working/png_file_dic/17100_549322384.png
#
# /kaggle/working/png_file_dic/40429_2038479013.png
#
# /kaggle/working/png_file_dic/54084_2125909748.png
#
# /kaggle/working/png_file_dic/30139_915895459.png
#
# /kaggle/working/png_file_dic/39557_1241322203.png
#
# /kaggle/working/png_file_dic/6368_1645949347.png
#
# /kaggle/working/png_file_dic/21464_1771134977.png
#
# /kaggle/working/png_file_dic/40911_1184408070.png
#
# /kaggle/working/png_file_dic/4817_607182039.png
#
# /kaggle/working/png_file_dic/54350_254286353.png
#
# /kaggle/working/png_file_dic/58540_1183328415.png
#
# /kaggle/working/png_file_dic/9515_52800506.png
#
# /kaggle/working/png_file_dic/12264_1825344557.png
#
# /kaggle/working/png_file_dic/36758_1746558067.png
#
# /kaggle/working/png_file_dic/22646_726039287.png
#
# /kaggle/working/png_file_dic/13317_1145659476.png
#
# /kaggle/working/png_file_dic/58526_1338975418.png
#
# /kaggle/working/png_file_dic/22667_1979267658.png
#
# /kaggle/working/png_file_dic/24231_1343655504.png
#
# /kaggle/working/png_file_dic/26463_2136873215.png
#
# /kaggle/working/png_file_dic/44136_1361962018.png
#
# /kaggle/working/png_file_dic/36669_490007833.png
#
# /kaggle/working/png_file_dic/61942_640716257.png
#
# /kaggle/working/png_file_dic/52901_1902902904.png
#
# /kaggle/working/png_file_dic/49857_1396557427.png
#
# /kaggle/working/png_file_dic/42408_2084576045.png
#
# /kaggle/working/png_file_dic/25669_2093063902.png
#
# /kaggle/working/png_file_dic/19033_1537123013.png
#
# /kaggle/working/png_file_dic/29010_1387281467.png
#
# /kaggle/working/png_file_dic/28308_92358603.png
#
# /kaggle/working/png_file_dic/18638_1182644547.png
#
# /kaggle/working/png_file_dic/58027_1601675959.png
#
# /kaggle/working/png_file_dic/64846_440925112.png
#
# /kaggle/working/png_file_dic/9795_39177266.png
#
# /kaggle/working/png_file_dic/48099_1856814725.png
#
# /kaggle/working/png_file_dic/10445_224398130.png
#
# /kaggle/working/png_file_dic/15550_1763899186.png
#
# /kaggle/working/png_file_dic/53086_2092312524.png
#
# /kaggle/working/png_file_dic/61404_1029710208.png
#
# /kaggle/working/png_file_dic/56632_1890161817.png
#
# /kaggle/working/png_file_dic/64557_1318659017.png
#
# /kaggle/working/png_file_dic/875_992970728.png
#
# /kaggle/working/png_file_dic/28043_172337301.png
#
# /kaggle/working/png_file_dic/44236_1166129258.png
#
# /kaggle/working/png_file_dic/16526_1917144602.png
#
# /kaggle/working/png_file_dic/55501_1250118052.png
#
# /kaggle/working/png_file_dic/46909_2023178109.png
#
# /kaggle/working/png_file_dic/14100_792791373.png
#
# /kaggle/working/png_file_dic/43498_1659770256.png
#
# /kaggle/working/png_file_dic/65491_1536994815.png
#
# /kaggle/working/png_file_dic/30262_1341819213.png
#
# /kaggle/working/png_file_dic/65222_111055050.png
#
# /kaggle/working/png_file_dic/20247_753498996.png
#
# /kaggle/working/png_file_dic/41781_1067589727.png
#
# /kaggle/working/png_file_dic/14850_285402677.png
#
# /kaggle/working/png_file_dic/50346_1011833840.png
#
# /kaggle/working/png_file_dic/52343_1049528813.png
#
# /kaggle/working/png_file_dic/9540_1511749837.png
#
# /kaggle/working/png_file_dic/7339_976373234.png
#
# /kaggle/working/png_file_dic/35706_925314757.png
#
# /kaggle/working/png_file_dic/57933_919043672.png
#
# /kaggle/working/png_file_dic/15494_11003818.png
#
# /kaggle/working/png_file_dic/39460_680981446.png
#
# /kaggle/working/png_file_dic/36378_10877375.png
#
# /kaggle/working/png_file_dic/16482_1629652788.png
#
# /kaggle/working/png_file_dic/39966_1536619274.png
#
# /kaggle/working/png_file_dic/64578_1661458083.png
#
# /kaggle/working/png_file_dic/41555_1632378192.png
#
# /kaggle/working/png_file_dic/46633_2115688981.png
#
# /kaggle/working/png_file_dic/34903_1096194917.png
#
# /kaggle/working/png_file_dic/46576_229197189.png
#
# /kaggle/working/png_file_dic/50174_1084331210.png
#
# /kaggle/working/png_file_dic/31345_1878545271.png
#
# /kaggle/working/png_file_dic/42662_1284107418.png
#
# /kaggle/working/png_file_dic/35109_558359774.png
#
# /kaggle/working/png_file_dic/56560_1448988913.png
#
# /kaggle/working/png_file_dic/40548_951691140.png
#
# /kaggle/working/png_file_dic/31191_1456521221.png
#
# /kaggle/working/png_file_dic/10232_1570900031.png
#
# /kaggle/working/png_file_dic/35421_1954231968.png
#
# /kaggle/working/png_file_dic/29889_1323165841.png
#
# /kaggle/working/png_file_dic/3807_1356924430.png
#
# /kaggle/working/png_file_dic/42527_1640312958.png
#
# /kaggle/working/png_file_dic/21245_307172175.png
#
# /kaggle/working/png_file_dic/42847_6054943.png
#
# /kaggle/working/png_file_dic/24916_378623093.png
#
# /kaggle/working/png_file_dic/63741_1518708473.png
#
# /kaggle/working/png_file_dic/56223_617360864.png
#
# /kaggle/working/png_file_dic/62851_410539147.png
#
# /kaggle/working/png_file_dic/35393_1882815321.png
#
# /kaggle/working/png_file_dic/51710_204459538.png
#
# /kaggle/working/png_file_dic/38909_579492722.png
#
# /kaggle/working/png_file_dic/25629_1306614214.png
#
# /kaggle/working/png_file_dic/2810_992242569.png
#
# /kaggle/working/png_file_dic/5218_1648180891.png
#
# /kaggle/working/png_file_dic/64766_306197189.png
#
# /kaggle/working/png_file_dic/15842_1744990656.png
#
# /kaggle/working/png_file_dic/45961_992213579.png
#
# /kaggle/working/png_file_dic/50736_307120525.png
#
# /kaggle/working/png_file_dic/46399_1232620699.png
#
# /kaggle/working/png_file_dic/64878_2020277104.png
#
# /kaggle/working/png_file_dic/43851_779425999.png
#
# /kaggle/working/png_file_dic/35040_1597250301.png
#
# /kaggle/working/png_file_dic/64055_673118377.png
#
# /kaggle/working/png_file_dic/26740_904066775.png
#
# /kaggle/working/png_file_dic/11098_1490995644.png
#
# /kaggle/working/png_file_dic/55941_928517648.png
#
# /kaggle/working/png_file_dic/58663_2044424750.png
#
# /kaggle/working/png_file_dic/12033_615051458.png
#
# /kaggle/working/png_file_dic/39514_91161495.png
#
# /kaggle/working/png_file_dic/49595_1058109976.png
#
# /kaggle/working/png_file_dic/1960_126238619.png
#
# /kaggle/working/png_file_dic/36769_254180421.png
#
# /kaggle/working/png_file_dic/14355_979468221.png
#
# /kaggle/working/png_file_dic/39692_937849901.png
#
# /kaggle/working/png_file_dic/1727_2127906581.png
#
# /kaggle/working/png_file_dic/55247_317305247.png
#
# /kaggle/working/png_file_dic/38712_1002671823.png
#
# /kaggle/working/png_file_dic/62520_1340916959.png
#
# /kaggle/working/png_file_dic/28396_1334326047.png
#
# /kaggle/working/png_file_dic/1368_1129130475.png
#
# /kaggle/working/png_file_dic/36690_438810349.png
#
# /kaggle/working/png_file_dic/24239_471715641.png
#
# /kaggle/working/png_file_dic/26091_2002996615.png
#
# /kaggle/working/png_file_dic/52268_1656919579.png
#
# /kaggle/working/png_file_dic/36420_141266182.png
#
# /kaggle/working/png_file_dic/59225_1945313855.png
#
# /kaggle/working/png_file_dic/43621_853626814.png
#
# /kaggle/working/png_file_dic/48977_1331649711.png
#
# /kaggle/working/png_file_dic/4564_1311306241.png
#
# /kaggle/working/png_file_dic/63114_1184273933.png
#
# /kaggle/working/png_file_dic/50688_484116172.png
#
# /kaggle/working/png_file_dic/57062_1296651610.png
#
# /kaggle/working/png_file_dic/23145_657011726.png
#
# /kaggle/working/png_file_dic/1625_1009635466.png
#
# /kaggle/working/png_file_dic/62269_1361768052.png
#
# /kaggle/working/png_file_dic/19306_464418949.png
#
# /kaggle/working/png_file_dic/63266_220222705.png
#
# /kaggle/working/png_file_dic/20690_269603241.png
#
# /kaggle/working/png_file_dic/56541_392619810.png
#
# /kaggle/working/png_file_dic/64603_279491704.png
#
# /kaggle/working/png_file_dic/37264_1997660666.png
#
# /kaggle/working/png_file_dic/12920_1505348565.png
#
# /kaggle/working/png_file_dic/30828_1916516690.png
#
# /kaggle/working/png_file_dic/15515_268517454.png
#
# /kaggle/working/png_file_dic/9573_1656991629.png
#
# /kaggle/working/png_file_dic/4812_1672714883.png
#
# /kaggle/working/png_file_dic/44628_1558326698.png
#
# /kaggle/working/png_file_dic/20909_1111204410.png
#
# /kaggle/working/png_file_dic/52990_1471149497.png
#
# /kaggle/working/png_file_dic/15259_239517752.png
#
# /kaggle/working/png_file_dic/60427_354196601.png
#
# /kaggle/working/png_file_dic/63123_1630986741.png
#
# /kaggle/working/png_file_dic/1015_114671324.png
#
# /kaggle/working/png_file_dic/34824_947955118.png
#
# /kaggle/working/png_file_dic/5799_811829111.png
#
# /kaggle/working/png_file_dic/63759_1766640524.png
#
# /kaggle/working/png_file_dic/18638_518289069.png
#
# /kaggle/working/png_file_dic/50078_552384131.png
#
# /kaggle/working/png_file_dic/27993_1893113149.png
#
# /kaggle/working/png_file_dic/62385_710148017.png
#
# /kaggle/working/png_file_dic/49016_56405314.png
#
# /kaggle/working/png_file_dic/14578_1546288565.png
#
# /kaggle/working/png_file_dic/19085_2108938784.png
#
# /kaggle/working/png_file_dic/7092_815636978.png
#
# /kaggle/working/png_file_dic/50028_135085944.png
#
# /kaggle/working/png_file_dic/15444_1205555300.png
#
# /kaggle/working/png_file_dic/17681_486130927.png
#
# /kaggle/working/png_file_dic/3855_2074440820.png
#
# /kaggle/working/png_file_dic/35300_656659022.png
#
# /kaggle/working/png_file_dic/62007_731501373.png
#
# /kaggle/working/png_file_dic/47416_1976494161.png
#
# /kaggle/working/png_file_dic/17507_1486009170.png
#
# /kaggle/working/png_file_dic/64300_1380910662.png
#
# /kaggle/working/png_file_dic/39600_629545101.png
#
# /kaggle/working/png_file_dic/31131_1348255940.png
#
# /kaggle/working/png_file_dic/6525_164075452.png
#
# /kaggle/working/png_file_dic/56713_1031105565.png
#
# /kaggle/working/png_file_dic/40429_786576802.png
#
# /kaggle/working/png_file_dic/33178_312401306.png
#
# /kaggle/working/png_file_dic/9141_1089655012.png
#
# /kaggle/working/png_file_dic/59653_312272467.png
#
# /kaggle/working/png_file_dic/25582_1992682946.png
#
# /kaggle/working/png_file_dic/7316_83071680.png
#
# /kaggle/working/png_file_dic/10302_2015998330.png
#
# /kaggle/working/png_file_dic/5202_2144024159.png
#
# /kaggle/working/png_file_dic/45349_1221216592.png
#
# /kaggle/working/png_file_dic/1067_1212417848.png
#
# /kaggle/working/png_file_dic/4896_994684262.png
#
# /kaggle/working/png_file_dic/41032_841461032.png
#
# /kaggle/working/png_file_dic/15525_225869822.png
#
# /kaggle/working/png_file_dic/5325_517967922.png
#
# /kaggle/working/png_file_dic/38944_1726923439.png
#
# /kaggle/working/png_file_dic/35279_1173485383.png
#
# /kaggle/working/png_file_dic/15896_1771709262.png
#
# /kaggle/working/png_file_dic/36157_391859411.png
#
# /kaggle/working/png_file_dic/9625_58889842.png
#
# /kaggle/working/png_file_dic/15709_1151079536.png
#
# /kaggle/working/png_file_dic/58195_480438532.png
#
# /kaggle/working/png_file_dic/364_1500913635.png
#
# /kaggle/working/png_file_dic/41647_2115055383.png
#
# /kaggle/working/png_file_dic/24564_360716168.png
#
# /kaggle/working/png_file_dic/36642_1258130983.png
#
# /kaggle/working/png_file_dic/59392_1845928419.png
#
# /kaggle/working/png_file_dic/55837_311881529.png
#
# /kaggle/working/png_file_dic/48678_1606046372.png
#
# /kaggle/working/png_file_dic/5834_1114247289.png
#
# /kaggle/working/png_file_dic/53565_816795392.png
#
# /kaggle/working/png_file_dic/40893_395369173.png
#
# /kaggle/working/png_file_dic/10302_2031965671.png
#
# /kaggle/working/png_file_dic/50257_69759295.png
#
# /kaggle/working/png_file_dic/7115_627914538.png
#
# /kaggle/working/png_file_dic/36563_700961017.png
#
# /kaggle/working/png_file_dic/29045_1479131466.png
#
# /kaggle/working/png_file_dic/47114_269937540.png
#
# /kaggle/working/png_file_dic/29791_2131278360.png
#
# /kaggle/working/png_file_dic/15591_581007994.png
#
# /kaggle/working/png_file_dic/9795_2064605838.png
#
# /kaggle/working/png_file_dic/10761_1924104560.png
#
# /kaggle/working/png_file_dic/5630_155467807.png
#
# /kaggle/working/png_file_dic/36894_312383276.png
#
# /kaggle/working/png_file_dic/56392_204428757.png
#
# /kaggle/working/png_file_dic/39291_1802760384.png
#
# /kaggle/working/png_file_dic/61934_1692203072.png
#
# /kaggle/working/png_file_dic/4935_1988013217.png
#
# /kaggle/working/png_file_dic/8872_491652408.png
#
# /kaggle/working/png_file_dic/34171_1683053209.png
#
# /kaggle/working/png_file_dic/55706_1754128804.png
#
# /kaggle/working/png_file_dic/9074_41879172.png
#
# /kaggle/working/png_file_dic/7984_1648035413.png
#
# /kaggle/working/png_file_dic/60522_1047435079.png
#
# /kaggle/working/png_file_dic/56576_1402688102.png
#
# /kaggle/working/png_file_dic/9130_1185889995.png
#
# /kaggle/working/png_file_dic/19791_627126677.png
#
# /kaggle/working/png_file_dic/21288_1179919236.png
#
# /kaggle/working/png_file_dic/2003_1270635927.png
#
# /kaggle/working/png_file_dic/21327_765612451.png
#
# /kaggle/working/png_file_dic/34655_1715567850.png
#
# /kaggle/working/png_file_dic/34671_581932941.png
#
# /kaggle/working/png_file_dic/3313_1554705481.png
#
# /kaggle/working/png_file_dic/1977_15003387.png
#
# /kaggle/working/png_file_dic/24608_567431455.png
#
# /kaggle/working/png_file_dic/15404_906010733.png
#
# /kaggle/working/png_file_dic/20352_1571637521.png
#
# /kaggle/working/png_file_dic/27306_1588576165.png
#
# /kaggle/working/png_file_dic/18243_1526540449.png
#
# /kaggle/working/png_file_dic/31727_516005787.png
#
# /kaggle/working/png_file_dic/18867_1283729079.png
#
# /kaggle/working/png_file_dic/29957_594080546.png
#
# /kaggle/working/png_file_dic/23759_1993804315.png
#
# /kaggle/working/png_file_dic/17961_175249091.png
#
# /kaggle/working/png_file_dic/16201_136529825.png
#
# /kaggle/working/png_file_dic/15433_1339389005.png
#
# /kaggle/working/png_file_dic/55811_1095400484.png
#
# /kaggle/working/png_file_dic/63123_782090589.png
#
# /kaggle/working/png_file_dic/25325_880801637.png
#
# /kaggle/working/png_file_dic/37536_802343698.png
#
# /kaggle/working/png_file_dic/33719_235404498.png
#
# /kaggle/working/png_file_dic/1147_1391694656.png
#
# /kaggle/working/png_file_dic/13749_2112271024.png
#
# /kaggle/working/png_file_dic/3126_16355052.png
#
# /kaggle/working/png_file_dic/7485_203799436.png
#
# /kaggle/working/png_file_dic/24086_320934778.png
#
# /kaggle/working/png_file_dic/44825_2001251363.png
#
# /kaggle/working/png_file_dic/65_1477365269.png
#
# /kaggle/working/png_file_dic/10736_274585100.png
#
# /kaggle/working/png_file_dic/6786_1106064145.png
#
# /kaggle/working/png_file_dic/10215_1856209291.png
#
# /kaggle/working/png_file_dic/44880_468358036.png
#
# /kaggle/working/png_file_dic/19383_1463959325.png
#
# /kaggle/working/png_file_dic/12026_242715512.png
#
# /kaggle/working/png_file_dic/4953_94584715.png
#
# /kaggle/working/png_file_dic/55148_1779819322.png
#
# /kaggle/working/png_file_dic/46598_649355717.png
#
# /kaggle/working/png_file_dic/40789_1115909630.png
#
# /kaggle/working/png_file_dic/32723_621829731.png
#
# /kaggle/working/png_file_dic/14687_813876175.png
#
# /kaggle/working/png_file_dic/62020_1984106586.png
#
# /kaggle/working/png_file_dic/62628_369783531.png
#
# /kaggle/working/png_file_dic/29169_492635806.png
#
# /kaggle/working/png_file_dic/33853_1257905746.png
#
# /kaggle/working/png_file_dic/36712_930762563.png
#
# /kaggle/working/png_file_dic/38744_1099726636.png
#
# /kaggle/working/png_file_dic/47186_1307131253.png
#
# /kaggle/working/png_file_dic/10335_1152574310.png
#
# /kaggle/working/png_file_dic/40437_966244222.png
#
# /kaggle/working/png_file_dic/23851_1204937970.png
#
# /kaggle/working/png_file_dic/51272_270656687.png
#
# /kaggle/working/png_file_dic/3755_1018167542.png
#
# /kaggle/working/png_file_dic/48146_2031516218.png
#
# /kaggle/working/png_file_dic/36215_1821970338.png
#
# /kaggle/working/png_file_dic/3947_937503477.png
#
# /kaggle/working/png_file_dic/8225_481794469.png
#
# /kaggle/working/png_file_dic/50866_1364682234.png
#
# /kaggle/working/png_file_dic/46891_1399284670.png
#
# /kaggle/working/png_file_dic/61803_1214815907.png
#
# /kaggle/working/png_file_dic/65309_630760671.png
#
# /kaggle/working/png_file_dic/55945_899469733.png
#
# /kaggle/working/png_file_dic/26805_288005635.png
#
# /kaggle/working/png_file_dic/36685_1991408265.png
#
# /kaggle/working/png_file_dic/63706_31978797.png
#
# /kaggle/working/png_file_dic/15444_613253184.png
#
# /kaggle/working/png_file_dic/37154_1599183112.png
#
# /kaggle/working/png_file_dic/40272_321555159.png
#
# /kaggle/working/png_file_dic/25304_1856007403.png
#
# /kaggle/working/png_file_dic/10528_463069660.png
#
# /kaggle/working/png_file_dic/38222_1556947939.png
#
# /kaggle/working/png_file_dic/65283_1586327403.png
#
# /kaggle/working/png_file_dic/11158_178475575.png
#
# /kaggle/working/png_file_dic/31811_1789961018.png
#
# /kaggle/working/png_file_dic/59265_191589670.png
#
# /kaggle/working/png_file_dic/602_2138348289.png
#
# /kaggle/working/png_file_dic/60885_1813741066.png
#
# /kaggle/working/png_file_dic/14106_1860329314.png
#
# /kaggle/working/png_file_dic/19689_1218630995.png
#
# /kaggle/working/png_file_dic/58477_2057408713.png
#
# /kaggle/working/png_file_dic/43924_55362883.png
#
# /kaggle/working/png_file_dic/29118_1380112717.png
#
# /kaggle/working/png_file_dic/64319_280634210.png
#
# /kaggle/working/png_file_dic/32663_1610769686.png
#
# /kaggle/working/png_file_dic/43745_2007774500.png
#
# /kaggle/working/png_file_dic/34982_352168729.png
#
# /kaggle/working/png_file_dic/52047_1825490460.png
#
# /kaggle/working/png_file_dic/35526_1596863013.png
#
# /kaggle/working/png_file_dic/16530_645692601.png
#
# /kaggle/working/png_file_dic/13731_268327264.png
#
# /kaggle/working/png_file_dic/21269_1315448879.png
#
# /kaggle/working/png_file_dic/22607_603017727.png
#
# /kaggle/working/png_file_dic/41240_1869401422.png
#
# /kaggle/working/png_file_dic/48334_491820221.png
#
# /kaggle/working/png_file_dic/60244_1895549666.png
#
# /kaggle/working/png_file_dic/61269_1139026101.png
#
# /kaggle/working/png_file_dic/55144_760957773.png
#
# /kaggle/working/png_file_dic/28028_391040684.png
#
# /kaggle/working/png_file_dic/46999_1462078343.png
#
# /kaggle/working/png_file_dic/959_935204233.png
#
# /kaggle/working/png_file_dic/59978_1187006041.png
#
# /kaggle/working/png_file_dic/9005_120084520.png
#
# /kaggle/working/png_file_dic/17845_430821356.png
#
# /kaggle/working/png_file_dic/51790_1841219356.png
#
# /kaggle/working/png_file_dic/48493_1325590980.png
#
# /kaggle/working/png_file_dic/60392_372283892.png
#
# /kaggle/working/png_file_dic/11745_1019636965.png
#
# /kaggle/working/png_file_dic/11278_738427556.png
#
# /kaggle/working/png_file_dic/51070_202641344.png
#
# /kaggle/working/png_file_dic/22706_1991011210.png
#
# /kaggle/working/png_file_dic/49823_1699387011.png
#
# /kaggle/working/png_file_dic/62104_1808008461.png
#
# /kaggle/working/png_file_dic/27034_682602673.png
#
# /kaggle/working/png_file_dic/14214_550004609.png
#
# /kaggle/working/png_file_dic/36430_1958228985.png
#
# /kaggle/working/png_file_dic/15285_1502578195.png
#
# /kaggle/working/png_file_dic/8338_1243486901.png
#
# /kaggle/working/png_file_dic/19630_2105722026.png
#
# /kaggle/working/png_file_dic/21739_230474701.png
#
# /kaggle/working/png_file_dic/41842_1436549060.png
#
# /kaggle/working/png_file_dic/31193_177035930.png
#
# /kaggle/working/png_file_dic/34971_1780130399.png
#
# /kaggle/working/png_file_dic/48997_1508270145.png
#
# /kaggle/working/png_file_dic/35847_150681526.png
#
# /kaggle/working/png_file_dic/22860_768375237.png
#
# /kaggle/working/png_file_dic/44709_714148567.png
#
# /kaggle/working/png_file_dic/43368_1424841808.png
#
# /kaggle/working/png_file_dic/53361_459125363.png
#
# /kaggle/working/png_file_dic/49340_622747180.png
#
# /kaggle/working/png_file_dic/3851_682994244.png
#
# /kaggle/working/png_file_dic/35445_1152664548.png
#
# /kaggle/working/png_file_dic/22528_1608847214.png
#
# /kaggle/working/png_file_dic/41038_2140691319.png
#
# /kaggle/working/png_file_dic/17183_357986204.png
#
# /kaggle/working/png_file_dic/12994_1990201709.png
#
# /kaggle/working/png_file_dic/45657_190932389.png
#
# /kaggle/working/png_file_dic/16577_609059149.png
#
# /kaggle/working/png_file_dic/11537_107226873.png
#
# /kaggle/working/png_file_dic/8997_272114586.png
#
# /kaggle/working/png_file_dic/3443_525998147.png
#
# /kaggle/working/png_file_dic/42526_1487029474.png
#
# /kaggle/working/png_file_dic/65337_1084196023.png
#
# /kaggle/working/png_file_dic/19613_846905781.png
#
# /kaggle/working/png_file_dic/26528_947382743.png
#
# /kaggle/working/png_file_dic/44198_1205059777.png
#
# /kaggle/working/png_file_dic/58004_1059718725.png
#
# /kaggle/working/png_file_dic/44713_1389588126.png
#
# /kaggle/working/png_file_dic/6003_1064041640.png
#
# /kaggle/working/png_file_dic/6077_1306946275.png
#
# /kaggle/working/png_file_dic/18351_1796974047.png
#
# /kaggle/working/png_file_dic/25075_1941837830.png
#
# /kaggle/working/png_file_dic/52516_165573702.png
#
# /kaggle/working/png_file_dic/14406_444581341.png
#
# /kaggle/working/png_file_dic/23375_1409979590.png
#
# /kaggle/working/png_file_dic/48773_381133458.png
#
# /kaggle/working/png_file_dic/58513_660914400.png
#
# /kaggle/working/png_file_dic/51556_959145836.png
#
# /kaggle/working/png_file_dic/39238_1610303261.png
#
# /kaggle/working/png_file_dic/29306_852522812.png
#
# /kaggle/working/png_file_dic/31056_1226699915.png
#
# /kaggle/working/png_file_dic/51905_951330285.png
#
# /kaggle/working/png_file_dic/44315_429692123.png
#
# /kaggle/working/png_file_dic/39683_784586086.png
#
# /kaggle/working/png_file_dic/28132_87065139.png
#
# /kaggle/working/png_file_dic/8860_83263805.png
#
# /kaggle/working/png_file_dic/57881_1025982834.png
#
# /kaggle/working/png_file_dic/2147_301869230.png
#
# /kaggle/working/png_file_dic/50236_1550556290.png
#
# /kaggle/working/png_file_dic/24130_15215508.png
#
# /kaggle/working/png_file_dic/21593_816040958.png
#
# /kaggle/working/png_file_dic/29670_369906792.png
#
# /kaggle/working/png_file_dic/50597_311689533.png
#
# /kaggle/working/png_file_dic/10672_1361228331.png
#
# /kaggle/working/png_file_dic/17273_103474131.png
#
# /kaggle/working/png_file_dic/54476_1390900003.png
#
# /kaggle/working/png_file_dic/16003_1715575979.png
#
# /kaggle/working/png_file_dic/62317_1364525264.png
#
# /kaggle/working/png_file_dic/26335_1897699505.png
#
# /kaggle/working/png_file_dic/28184_1812975094.png
#
# /kaggle/working/png_file_dic/53113_1209596793.png
#
# /kaggle/working/png_file_dic/30941_1182945838.png
#
# /kaggle/working/png_file_dic/1357_1035324909.png
#
# /kaggle/working/png_file_dic/61631_643241581.png
#
# /kaggle/working/png_file_dic/39263_602209203.png
#
# /kaggle/working/png_file_dic/12842_632448935.png
#
# /kaggle/working/png_file_dic/61404_922716159.png
#
# /kaggle/working/png_file_dic/46715_1135673284.png
#
# /kaggle/working/png_file_dic/58858_488009578.png
#
# /kaggle/working/png_file_dic/12401_1201709287.png
#
# /kaggle/working/png_file_dic/3102_59850091.png
#
# /kaggle/working/png_file_dic/37381_1651111918.png
#
# /kaggle/working/png_file_dic/23909_2078079301.png
#
# /kaggle/working/png_file_dic/22023_1852576752.png
#
# /kaggle/working/png_file_dic/60476_1065622949.png
#
# /kaggle/working/png_file_dic/60880_896794279.png
#
# /kaggle/working/png_file_dic/58716_479353557.png
#
# /kaggle/working/png_file_dic/23604_597902957.png
#
# /kaggle/working/png_file_dic/48985_792488418.png
#
# /kaggle/working/png_file_dic/48042_1582932172.png
#
# /kaggle/working/png_file_dic/25671_1312158544.png
#
# /kaggle/working/png_file_dic/50450_1890205208.png
#
# /kaggle/working/png_file_dic/32225_531124157.png
#
# /kaggle/working/png_file_dic/56766_1981809271.png
#
# /kaggle/working/png_file_dic/13909_1939963533.png
#
# /kaggle/working/png_file_dic/16346_822395080.png
#
# /kaggle/working/png_file_dic/56950_1221642981.png
#
# /kaggle/working/png_file_dic/25540_2075705780.png
#
# /kaggle/working/png_file_dic/13900_1649956097.png
#
# /kaggle/working/png_file_dic/37106_686421885.png
#
# /kaggle/working/png_file_dic/21687_1444965796.png
#
# /kaggle/working/png_file_dic/51608_1995585958.png
#
# /kaggle/working/png_file_dic/7056_1965997241.png
#
# /kaggle/working/png_file_dic/3832_1493887775.png
#
# /kaggle/working/png_file_dic/50740_767338058.png
#
# /kaggle/working/png_file_dic/16976_2096460417.png
#
# /kaggle/working/png_file_dic/51278_1340734269.png
#
# /kaggle/working/png_file_dic/58616_1379101403.png
#
# /kaggle/working/png_file_dic/2023_715690326.png
#
# /kaggle/working/png_file_dic/25225_268072316.png
#
# /kaggle/working/png_file_dic/44055_80577254.png
#
# /kaggle/working/png_file_dic/30_1153448462.png
#
# /kaggle/working/png_file_dic/9968_2098937312.png
#
# /kaggle/working/png_file_dic/14778_1192557800.png
#
# /kaggle/working/png_file_dic/59265_1533634388.png
#
# /kaggle/working/png_file_dic/21711_1869378096.png
#
# /kaggle/working/png_file_dic/27083_1992007340.png
#
# /kaggle/working/png_file_dic/50558_210915830.png
#
# /kaggle/working/png_file_dic/10506_1226238477.png
#
# /kaggle/working/png_file_dic/47622_277328709.png
#
# /kaggle/working/png_file_dic/48502_1766697432.png
#
# /kaggle/working/png_file_dic/51959_566565884.png
#
# /kaggle/working/png_file_dic/16631_840797550.png
#
# /kaggle/working/png_file_dic/22100_1521781455.png
#
# /kaggle/working/png_file_dic/46299_2041207498.png
#
# /kaggle/working/png_file_dic/39126_1464668746.png
#
# /kaggle/working/png_file_dic/45942_1823686734.png
#
# /kaggle/working/png_file_dic/42261_2018894568.png
#
# /kaggle/working/png_file_dic/32445_1698741285.png
#
# /kaggle/working/png_file_dic/39966_215375685.png
#
# /kaggle/working/png_file_dic/12258_1433775262.png
#
# /kaggle/working/png_file_dic/24782_288765902.png
#
# /kaggle/working/png_file_dic/5748_728607250.png
#
# /kaggle/working/png_file_dic/65427_237373871.png
#
# /kaggle/working/png_file_dic/60391_71611500.png
#
# /kaggle/working/png_file_dic/64821_1471452228.png
#
# /kaggle/working/png_file_dic/46240_454720160.png
#
# /kaggle/working/png_file_dic/5568_539277706.png
#
# /kaggle/working/png_file_dic/53517_2085629244.png
#
# /kaggle/working/png_file_dic/62448_2083758323.png
#
# /kaggle/working/png_file_dic/17570_130190871.png
#
# /kaggle/working/png_file_dic/55912_334095913.png
#
# /kaggle/working/png_file_dic/63836_1109952609.png
#
# /kaggle/working/png_file_dic/37518_585259225.png
#
# /kaggle/working/png_file_dic/26644_561840634.png
#
# /kaggle/working/png_file_dic/21715_240718488.png
#
# /kaggle/working/png_file_dic/22230_1218029741.png
#
# /kaggle/working/png_file_dic/613_1363944683.png
#
# /kaggle/working/png_file_dic/26591_1614073900.png
#
# /kaggle/working/png_file_dic/64106_37137550.png
#
# /kaggle/working/png_file_dic/41379_1143204221.png
#
# /kaggle/working/png_file_dic/40238_1440496518.png
#
# /kaggle/working/png_file_dic/52920_1277698550.png
#
# /kaggle/working/png_file_dic/33954_2056149529.png
#
# /kaggle/working/png_file_dic/44971_1836581191.png
#
# /kaggle/working/png_file_dic/5134_127937089.png
#
# /kaggle/working/png_file_dic/44505_1108639727.png
#
# /kaggle/working/png_file_dic/54767_744780991.png
#
# /kaggle/working/png_file_dic/2539_1802131267.png
#
# /kaggle/working/png_file_dic/26286_2080001420.png
#
# /kaggle/working/png_file_dic/17034_1330301897.png
#
# /kaggle/working/png_file_dic/115_503361456.png
#
# /kaggle/working/png_file_dic/15662_389050055.png
#
# /kaggle/working/png_file_dic/33953_1631523792.png
#
# /kaggle/working/png_file_dic/41047_760544214.png
#
# /kaggle/working/png_file_dic/34603_1675354903.png
#
# /kaggle/working/png_file_dic/49151_443006806.png
#
# /kaggle/working/png_file_dic/61198_1672115536.png
#
# /kaggle/working/png_file_dic/986_1214188251.png
#
# /kaggle/working/png_file_dic/39850_1940095769.png
#
# /kaggle/working/png_file_dic/27447_263901674.png
#
# /kaggle/working/png_file_dic/13366_1734488804.png
#
# /kaggle/working/png_file_dic/24845_1419558211.png
#
# /kaggle/working/png_file_dic/63154_2119015945.png
#
# /kaggle/working/png_file_dic/17610_860225967.png
#
# /kaggle/working/png_file_dic/6496_1328650671.png
#
# /kaggle/working/png_file_dic/37358_387709760.png
#
# /kaggle/working/png_file_dic/25733_845123534.png
#
# /kaggle/working/png_file_dic/56460_1251768212.png
#
# /kaggle/working/png_file_dic/49827_615340666.png
#
# /kaggle/working/png_file_dic/38457_895944168.png
#
# /kaggle/working/png_file_dic/53777_811073543.png
#
# /kaggle/working/png_file_dic/18274_1878708390.png
#
# /kaggle/working/png_file_dic/27674_155246462.png
#
# /kaggle/working/png_file_dic/35169_2043152570.png
#
# /kaggle/working/png_file_dic/57015_1581949085.png
#
# /kaggle/working/png_file_dic/2454_904734367.png
#
# /kaggle/working/png_file_dic/46694_1438589166.png
#
# /kaggle/working/png_file_dic/54696_420999944.png
#
# /kaggle/working/png_file_dic/42109_1764175319.png
#
# /kaggle/working/png_file_dic/46832_2143874204.png
#
# /kaggle/working/png_file_dic/37668_1128524229.png
#
# /kaggle/working/png_file_dic/61688_1513474014.png
#
# /kaggle/working/png_file_dic/63554_351909874.png
#
# /kaggle/working/png_file_dic/29169_1219501838.png
#
# /kaggle/working/png_file_dic/15237_48965924.png
#
# /kaggle/working/png_file_dic/53678_646987930.png
#
# /kaggle/working/png_file_dic/27089_2005117804.png
#
# /kaggle/working/png_file_dic/41069_1995390348.png
#
# /kaggle/working/png_file_dic/38944_1003240946.png
#
# /kaggle/working/png_file_dic/2488_2130623709.png
#
# /kaggle/working/png_file_dic/62563_797481386.png
#
# /kaggle/working/png_file_dic/19353_1571982223.png
#
# /kaggle/working/png_file_dic/5993_952543835.png
#
# /kaggle/working/png_file_dic/53132_768557566.png
#
# /kaggle/working/png_file_dic/53070_1784526286.png
#
# /kaggle/working/png_file_dic/39656_1450929950.png
#
# /kaggle/working/png_file_dic/58874_1736401520.png
#
# /kaggle/working/png_file_dic/47656_66049836.png
#
# /kaggle/working/png_file_dic/29898_166573135.png
#
# /kaggle/working/png_file_dic/38702_1704399001.png
#
# /kaggle/working/png_file_dic/35300_1907429247.png
#
# /kaggle/working/png_file_dic/42662_1118473680.png
#
# /kaggle/working/png_file_dic/12901_2135373440.png
#
# /kaggle/working/png_file_dic/22012_1899316554.png
#
# /kaggle/working/png_file_dic/2708_1301698665.png
#
# /kaggle/working/png_file_dic/45872_1981485950.png
#
# /kaggle/working/png_file_dic/12393_118544819.png
#
# /kaggle/working/png_file_dic/33583_1301721360.png
#
# /kaggle/working/png_file_dic/50788_608715672.png
#
# /kaggle/working/png_file_dic/39684_1907402262.png
#
# /kaggle/working/png_file_dic/59626_436812825.png
#
# /kaggle/working/png_file_dic/48295_449130630.png
#
# /kaggle/working/png_file_dic/51490_164313204.png
#
# /kaggle/working/png_file_dic/1717_1896490677.png
#
# /kaggle/working/png_file_dic/19094_1210940582.png
#
# /kaggle/working/png_file_dic/37101_1625930141.png
#
# /kaggle/working/png_file_dic/18641_801449807.png
#
# /kaggle/working/png_file_dic/41183_530779289.png
#
# /kaggle/working/png_file_dic/37365_1545406597.png
#
# /kaggle/working/png_file_dic/13995_1343703233.png
#
# /kaggle/working/png_file_dic/42460_897111401.png
#
# /kaggle/working/png_file_dic/55057_1492047265.png
#
# /kaggle/working/png_file_dic/17892_1283964415.png
#
# /kaggle/working/png_file_dic/5286_1965393237.png
#
# /kaggle/working/png_file_dic/2738_1154819623.png
#
# /kaggle/working/png_file_dic/35595_1953895680.png
#
# /kaggle/working/png_file_dic/40537_2070313242.png
#
# /kaggle/working/png_file_dic/44021_1796011713.png
#
# /kaggle/working/png_file_dic/58276_2033601050.png
#
# /kaggle/working/png_file_dic/44745_592955661.png
#
# /kaggle/working/png_file_dic/6708_1103942809.png
#
# /kaggle/working/png_file_dic/15842_1843719284.png
#
# /kaggle/working/png_file_dic/22213_367826042.png
#
# /kaggle/working/png_file_dic/25319_1620084924.png
#
# /kaggle/working/png_file_dic/29899_586101376.png
#
# /kaggle/working/png_file_dic/30247_1978018832.png
#
# /kaggle/working/png_file_dic/30939_1384091150.png
#
# /kaggle/working/png_file_dic/1185_1076502758.png
#
# /kaggle/working/png_file_dic/6659_630551380.png
#
# /kaggle/working/png_file_dic/4711_1101950826.png
#
# /kaggle/working/png_file_dic/30508_1343150394.png
#
# /kaggle/working/png_file_dic/52021_2080178038.png
#
# /kaggle/working/png_file_dic/39667_1909863018.png
#
# /kaggle/working/png_file_dic/65095_1452212249.png
#
# /kaggle/working/png_file_dic/65495_1435151627.png
#
# /kaggle/working/png_file_dic/14981_1304554432.png
#
# /kaggle/working/png_file_dic/56182_1831067704.png
#
# /kaggle/working/png_file_dic/8393_740531930.png
#
# /kaggle/working/png_file_dic/53999_325945481.png
#
# /kaggle/working/png_file_dic/33418_1187265667.png
#
# /kaggle/working/png_file_dic/12599_97564423.png
#
# /kaggle/working/png_file_dic/1203_1156504489.png
#
# /kaggle/working/png_file_dic/59839_1513616678.png
#
# /kaggle/working/png_file_dic/22049_468699518.png
#
# /kaggle/working/png_file_dic/56070_116762578.png
#
# /kaggle/working/png_file_dic/16598_1938055275.png
#
# /kaggle/working/png_file_dic/31629_1561866210.png
#
# /kaggle/working/png_file_dic/16864_739681015.png
#
# /kaggle/working/png_file_dic/924_2075555904.png
#
# /kaggle/working/png_file_dic/48042_599175404.png
#
# /kaggle/working/png_file_dic/6334_2117042846.png
#
# /kaggle/working/png_file_dic/4285_1568107958.png
#
# /kaggle/working/png_file_dic/32977_1529423287.png
#
# /kaggle/working/png_file_dic/25303_1454916112.png
#
# /kaggle/working/png_file_dic/51993_333889748.png
#
# /kaggle/working/png_file_dic/54832_2067876460.png
#
# /kaggle/working/png_file_dic/64309_1721930898.png
#
# /kaggle/working/png_file_dic/61141_481129844.png
#
# /kaggle/working/png_file_dic/39238_1697986636.png
#
# /kaggle/working/png_file_dic/15382_2137698543.png
#
# /kaggle/working/png_file_dic/6340_840717253.png
#
# /kaggle/working/png_file_dic/38037_400337792.png
#
# /kaggle/working/png_file_dic/51717_1080961656.png
#
# /kaggle/working/png_file_dic/14136_693140301.png
#
# /kaggle/working/png_file_dic/56034_1099777037.png
#
# /kaggle/working/png_file_dic/23482_1557454536.png
#
# /kaggle/working/png_file_dic/21649_1619153940.png
#
# /kaggle/working/png_file_dic/38784_975777577.png
#
# /kaggle/working/png_file_dic/53398_954234596.png
#
# /kaggle/working/png_file_dic/31261_1409681982.png
#
# /kaggle/working/png_file_dic/30512_1716041932.png
#
# /kaggle/working/png_file_dic/26748_2122327268.png
#
# /kaggle/working/png_file_dic/5696_1601747142.png
#
# /kaggle/working/png_file_dic/8842_1780005471.png
#
# /kaggle/working/png_file_dic/28308_630687029.png
#
# /kaggle/working/png_file_dic/32252_187375781.png
#
# /kaggle/working/png_file_dic/31663_943217302.png
#
# /kaggle/working/png_file_dic/55242_1097732044.png
#
# /kaggle/working/png_file_dic/16580_38223454.png
#
# /kaggle/working/png_file_dic/16699_1667623374.png
#
# /kaggle/working/png_file_dic/16042_1408068438.png
#
# /kaggle/working/png_file_dic/28747_1978711368.png
#
# /kaggle/working/png_file_dic/15736_1461205492.png
#
# /kaggle/working/png_file_dic/52261_884499128.png
#
# /kaggle/working/png_file_dic/4277_1588611602.png
#
# /kaggle/working/png_file_dic/58897_1021639954.png
#
# /kaggle/working/png_file_dic/54300_474840120.png
#
# /kaggle/working/png_file_dic/6039_558368364.png
#
# /kaggle/working/png_file_dic/8545_47245736.png
#
# /kaggle/working/png_file_dic/18243_1362357046.png
#
# /kaggle/working/png_file_dic/18522_99090205.png
#
# /kaggle/working/png_file_dic/51822_1582239952.png
#
# /kaggle/working/png_file_dic/18984_899655057.png
#
# /kaggle/working/png_file_dic/8050_283575829.png
#
# /kaggle/working/png_file_dic/24675_1396938747.png
#
# /kaggle/working/png_file_dic/16688_297665361.png
#
# /kaggle/working/png_file_dic/61720_1109380303.png
#
# /kaggle/working/png_file_dic/34645_843397584.png
#
# /kaggle/working/png_file_dic/28059_1456940701.png
#
# /kaggle/working/png_file_dic/58802_1683477119.png
#
# /kaggle/working/png_file_dic/26232_526928038.png
#
# /kaggle/working/png_file_dic/7927_1452662349.png
#
# /kaggle/working/png_file_dic/24943_348100450.png
#
# /kaggle/working/png_file_dic/24916_1935805685.png
#
# /kaggle/working/png_file_dic/6853_572494260.png
#
# /kaggle/working/png_file_dic/28174_1738462332.png
#
# /kaggle/working/png_file_dic/4244_744069101.png
#
# /kaggle/working/png_file_dic/40747_716571709.png
#
# /kaggle/working/png_file_dic/33126_1628809968.png
#
# /kaggle/working/png_file_dic/23035_1937699038.png
#
# /kaggle/working/png_file_dic/19921_1601927595.png
#
# /kaggle/working/png_file_dic/21738_976572825.png
#
# /kaggle/working/png_file_dic/32314_1585223072.png
#
# /kaggle/working/png_file_dic/17209_443076428.png
#
# /kaggle/working/png_file_dic/26161_1721153152.png
#
# /kaggle/working/png_file_dic/3411_821274420.png
#
# /kaggle/working/png_file_dic/58093_168415749.png
#
# /kaggle/working/png_file_dic/38208_180811780.png
#
# /kaggle/working/png_file_dic/48994_1401008057.png
#
# /kaggle/working/png_file_dic/13129_124915689.png
#
# /kaggle/working/png_file_dic/51944_1850040293.png
#
# /kaggle/working/png_file_dic/6038_1576775200.png
#
# /kaggle/working/png_file_dic/28230_1902509628.png
#
# /kaggle/working/png_file_dic/4051_1343296853.png
#
# /kaggle/working/png_file_dic/38930_2110654839.png
#
# /kaggle/working/png_file_dic/3351_1326743098.png
#
# /kaggle/working/png_file_dic/59549_457600713.png
#
# /kaggle/working/png_file_dic/48506_1556481992.png
#
# /kaggle/working/png_file_dic/10817_1663306587.png
#
# /kaggle/working/png_file_dic/27875_307854208.png
#
# /kaggle/working/png_file_dic/28733_1567232659.png
#
# /kaggle/working/png_file_dic/12501_785986826.png
#
# /kaggle/working/png_file_dic/34642_198290489.png
#
# /kaggle/working/png_file_dic/5250_546925910.png
#
# /kaggle/working/png_file_dic/7307_363190024.png
#
# /kaggle/working/png_file_dic/13312_340896505.png
#
# /kaggle/working/png_file_dic/52143_935597108.png
#
# /kaggle/working/png_file_dic/58392_1216072553.png
#
# /kaggle/working/png_file_dic/41103_1963187060.png
#
# /kaggle/working/png_file_dic/44250_1403117425.png
#
# /kaggle/working/png_file_dic/22800_1427351467.png
#
# /kaggle/working/png_file_dic/16863_1140863275.png
#
# /kaggle/working/png_file_dic/41421_2075366640.png
#
# /kaggle/working/png_file_dic/38170_259363251.png
#
# /kaggle/working/png_file_dic/36590_83218100.png
#
# /kaggle/working/png_file_dic/2264_1053601684.png
#
# /kaggle/working/png_file_dic/39134_392430243.png
#
# /kaggle/working/png_file_dic/62560_757717984.png
#
# /kaggle/working/png_file_dic/33977_1364604545.png
#
# /kaggle/working/png_file_dic/63388_1067906771.png
#
# /kaggle/working/png_file_dic/32582_1753431155.png
#
# /kaggle/working/png_file_dic/38848_1056338962.png
#
# /kaggle/working/png_file_dic/44351_46550501.png
#
# /kaggle/working/png_file_dic/24572_410708645.png
#
# /kaggle/working/png_file_dic/43262_2045888125.png
#
# /kaggle/working/png_file_dic/34779_143127119.png
#
# /kaggle/working/png_file_dic/47114_1788087091.png
#
# /kaggle/working/png_file_dic/38466_1630152471.png
#
# /kaggle/working/png_file_dic/15018_1819718442.png
#
# /kaggle/working/png_file_dic/45355_800828958.png
#
# /kaggle/working/png_file_dic/12855_2013086862.png
#
# /kaggle/working/png_file_dic/37051_1296943954.png
#
# /kaggle/working/png_file_dic/33100_1454593922.png
#
# /kaggle/working/png_file_dic/6896_1420689748.png
#
# /kaggle/working/png_file_dic/9767_118571683.png
#
# /kaggle/working/png_file_dic/15793_56859322.png
#
# /kaggle/working/png_file_dic/61259_418713603.png
#
# /kaggle/working/png_file_dic/46373_1589522246.png
#
# /kaggle/working/png_file_dic/64273_1837382908.png
#
# /kaggle/working/png_file_dic/25906_91217771.png
#
# /kaggle/working/png_file_dic/4822_1805141127.png
#
# /kaggle/working/png_file_dic/55783_1260597220.png
#
# /kaggle/working/png_file_dic/58124_820795275.png
#
# /kaggle/working/png_file_dic/58635_803930562.png
#
# /kaggle/working/png_file_dic/50604_1757115706.png
#
# /kaggle/working/png_file_dic/36164_927654915.png
#
# /kaggle/working/png_file_dic/9028_1625798348.png
#
# /kaggle/working/png_file_dic/30579_1052826706.png
#
# /kaggle/working/png_file_dic/25679_1160860283.png
#
# /kaggle/working/png_file_dic/27365_1017274538.png
#
# /kaggle/working/png_file_dic/64411_2036639365.png
#
# /kaggle/working/png_file_dic/12571_489108448.png
#
# /kaggle/working/png_file_dic/34655_1032257144.png
#
# /kaggle/working/png_file_dic/26106_854888791.png
#
# /kaggle/working/png_file_dic/35008_1166536156.png
#
# /kaggle/working/png_file_dic/61508_777913500.png
#
# /kaggle/working/png_file_dic/59814_1093600780.png
#
# /kaggle/working/png_file_dic/45441_840013652.png
#
# /kaggle/working/png_file_dic/26472_2099832232.png
#
# /kaggle/working/png_file_dic/56716_1824821229.png
#
# /kaggle/working/png_file_dic/43924_588258015.png
#
# /kaggle/working/png_file_dic/2152_408162584.png
#
# /kaggle/working/png_file_dic/6687_615787358.png
#
# /kaggle/working/png_file_dic/12734_1307513563.png
#
# /kaggle/working/png_file_dic/58087_239228878.png
#
# /kaggle/working/png_file_dic/1783_506825270.png
#
# /kaggle/working/png_file_dic/30653_1090412552.png
#
# /kaggle/working/png_file_dic/38107_2133670520.png
#
# /kaggle/working/png_file_dic/29552_1362288007.png
#
# /kaggle/working/png_file_dic/49143_324658293.png
#
# /kaggle/working/png_file_dic/12934_1757717962.png
#
# /kaggle/working/png_file_dic/1360_155546057.png
#
# /kaggle/working/png_file_dic/42779_356867681.png
#
# /kaggle/working/png_file_dic/55319_1786677517.png
#
# /kaggle/working/png_file_dic/24057_1956088639.png
#
# /kaggle/working/png_file_dic/36438_672993734.png
#
# /kaggle/working/png_file_dic/30504_771732894.png
#
# /kaggle/working/png_file_dic/36943_1507267171.png
#
# /kaggle/working/png_file_dic/52566_713126223.png
#
# /kaggle/working/png_file_dic/61259_1501036984.png
#
# /kaggle/working/png_file_dic/26889_2016437426.png
#
# /kaggle/working/png_file_dic/61967_1742624152.png
#
# /kaggle/working/png_file_dic/49640_1037156060.png
#
# /kaggle/working/png_file_dic/51070_1336343364.png
#
# /kaggle/working/png_file_dic/60299_1254972409.png
#
# /kaggle/working/png_file_dic/36204_1687449746.png
#
# /kaggle/working/png_file_dic/59704_1318189434.png
#
# /kaggle/working/png_file_dic/55910_1701478852.png
#
# /kaggle/working/png_file_dic/15055_1212964392.png
#
# /kaggle/working/png_file_dic/33736_1127383363.png
#
# /kaggle/working/png_file_dic/8974_2084548833.png
#
# /kaggle/working/png_file_dic/20787_1232060297.png
#
# /kaggle/working/png_file_dic/20337_1784145560.png
#
# /kaggle/working/png_file_dic/46576_722928797.png
#
# /kaggle/working/png_file_dic/14624_1169152491.png
#
# /kaggle/working/png_file_dic/15756_919855065.png
#
# /kaggle/working/png_file_dic/31291_55265559.png
#
# /kaggle/working/png_file_dic/33260_1486499374.png
#
# /kaggle/working/png_file_dic/55690_1444277838.png
#
# /kaggle/working/png_file_dic/59305_2065970439.png
#
# /kaggle/working/png_file_dic/41926_1675421758.png
#
# /kaggle/working/png_file_dic/45269_1861434243.png
#
# /kaggle/working/png_file_dic/2179_2039865970.png
#
# /kaggle/working/png_file_dic/59529_287010680.png
#
# /kaggle/working/png_file_dic/13365_575327269.png
#
# /kaggle/working/png_file_dic/10959_1104544219.png
#
# /kaggle/working/png_file_dic/12358_2063250554.png
#
# /kaggle/working/png_file_dic/10539_807551796.png
#
# /kaggle/working/png_file_dic/64466_1321200617.png
#
# /kaggle/working/png_file_dic/50232_26921443.png
#
# /kaggle/working/png_file_dic/30187_63266771.png
#
# /kaggle/working/png_file_dic/54688_1906991500.png
#
# /kaggle/working/png_file_dic/44543_1962956716.png
#
# /kaggle/working/png_file_dic/21288_1462397306.png
#
# /kaggle/working/png_file_dic/33749_2140651207.png
#
# /kaggle/working/png_file_dic/7041_1233432050.png
#
# /kaggle/working/png_file_dic/31727_546937606.png
#
# /kaggle/working/png_file_dic/18436_1446857204.png
#
# /kaggle/working/png_file_dic/12101_1360205675.png
#
# /kaggle/working/png_file_dic/22062_1184000077.png
#
# /kaggle/working/png_file_dic/52033_1256751165.png
#
# /kaggle/working/png_file_dic/15551_2065061464.png
#
# /kaggle/working/png_file_dic/53749_1235702284.png
#
# /kaggle/working/png_file_dic/46517_2117430328.png
#
# /kaggle/working/png_file_dic/46772_1399571346.png
#
# /kaggle/working/png_file_dic/32191_1049790067.png
#
# /kaggle/working/png_file_dic/28713_769263345.png
#
# /kaggle/working/png_file_dic/5504_569755617.png
#
# /kaggle/working/png_file_dic/61443_928219557.png
#
# /kaggle/working/png_file_dic/26006_640844088.png
#
# /kaggle/working/png_file_dic/23035_1505727762.png
#
# /kaggle/working/png_file_dic/40602_952567499.png
#
# /kaggle/working/png_file_dic/60289_843461943.png
#
# /kaggle/working/png_file_dic/4513_1543202055.png
#
# /kaggle/working/png_file_dic/31030_1664058227.png
#
# /kaggle/working/png_file_dic/34686_1254749305.png
#
# /kaggle/working/png_file_dic/26468_1422307029.png
#
# /kaggle/working/png_file_dic/55724_1340074044.png
#
# /kaggle/working/png_file_dic/61178_991559468.png
#
# /kaggle/working/png_file_dic/16055_799682815.png
#
# /kaggle/working/png_file_dic/52148_1600226389.png
#
# /kaggle/working/png_file_dic/16788_1853380580.png
#
# /kaggle/working/png_file_dic/50251_2107047187.png
#
# /kaggle/working/png_file_dic/47699_1086111483.png
#
# /kaggle/working/png_file_dic/24908_738926519.png
#
# /kaggle/working/png_file_dic/16124_1300489913.png
#
# /kaggle/working/png_file_dic/53852_29403298.png
#
# /kaggle/working/png_file_dic/14091_472403695.png
#
# /kaggle/working/png_file_dic/22562_184187010.png
#
# /kaggle/working/png_file_dic/64227_1646707246.png
#
# /kaggle/working/png_file_dic/29314_1494076531.png
#
# /kaggle/working/png_file_dic/6043_1817654839.png
#
# /kaggle/working/png_file_dic/51012_1763574028.png
#
# /kaggle/working/png_file_dic/5429_411442507.png
#
# /kaggle/working/png_file_dic/35295_1398930030.png
#
# /kaggle/working/png_file_dic/56813_1923655631.png
#
# /kaggle/working/png_file_dic/21720_1949604033.png
#
# /kaggle/working/png_file_dic/3435_1757644030.png
#
# /kaggle/working/png_file_dic/26048_505474931.png
#
# /kaggle/working/png_file_dic/19750_684882869.png
#
# /kaggle/working/png_file_dic/60629_1069033855.png
#
# /kaggle/working/png_file_dic/49397_1930701248.png
#
# /kaggle/working/png_file_dic/58552_1378004879.png
#
# /kaggle/working/png_file_dic/58069_22497500.png
#
# /kaggle/working/png_file_dic/26879_756218093.png
#
# /kaggle/working/png_file_dic/8790_1216118391.png
#
# /kaggle/working/png_file_dic/43237_1806577122.png
#
# /kaggle/working/png_file_dic/25504_1112707629.png
#
# /kaggle/working/png_file_dic/17834_1445404176.png
#
# /kaggle/working/png_file_dic/46136_831635365.png
#
# /kaggle/working/png_file_dic/57784_1460445309.png
#
# /kaggle/working/png_file_dic/37722_1781922058.png
#
# /kaggle/working/png_file_dic/30462_125844377.png
#
# /kaggle/working/png_file_dic/15009_1595538762.png
#
# /kaggle/working/png_file_dic/44389_29456927.png
#
# /kaggle/working/png_file_dic/32591_2113316216.png
#
# /kaggle/working/png_file_dic/61803_1606535242.png
#
# /kaggle/working/png_file_dic/48033_1748525607.png
#
# /kaggle/working/png_file_dic/31176_139215659.png
#
# /kaggle/working/png_file_dic/54884_1505116160.png
#
# /kaggle/working/png_file_dic/12429_1395839147.png
#
# /kaggle/working/png_file_dic/55657_239065421.png
#
# /kaggle/working/png_file_dic/61527_964564454.png
#
# /kaggle/working/png_file_dic/45859_839870028.png
#
# /kaggle/working/png_file_dic/21400_1312089242.png
#
# /kaggle/working/png_file_dic/37035_1271838661.png
#
# /kaggle/working/png_file_dic/64673_62012469.png
#
# /kaggle/working/png_file_dic/26380_1100193755.png
#
# /kaggle/working/png_file_dic/2923_370141925.png
#
# /kaggle/working/png_file_dic/1122_1791019677.png
#
# /kaggle/working/png_file_dic/2663_738438601.png
#
# /kaggle/working/png_file_dic/42714_788640429.png
#
# /kaggle/working/png_file_dic/57798_1326164928.png
#
# /kaggle/working/png_file_dic/17711_2085109401.png
#
# /kaggle/working/png_file_dic/50229_1324334766.png
#
# /kaggle/working/png_file_dic/6104_925133109.png
#
# /kaggle/working/png_file_dic/7935_692546941.png
#
# /kaggle/working/png_file_dic/49448_434068700.png
#
# /kaggle/working/png_file_dic/17905_214786160.png
#
# /kaggle/working/png_file_dic/24243_1915026110.png
#
# /kaggle/working/png_file_dic/49143_230456893.png
#
# /kaggle/working/png_file_dic/15313_225262254.png
#
# /kaggle/working/png_file_dic/15900_2011754958.png
#
# /kaggle/working/png_file_dic/34992_1491311346.png
#
# /kaggle/working/png_file_dic/61527_722947134.png
#
# /kaggle/working/png_file_dic/5505_1018763096.png
#
# /kaggle/working/png_file_dic/39800_76858229.png
#
# /kaggle/working/png_file_dic/3973_1121473454.png
#
# /kaggle/working/png_file_dic/39601_1385770043.png
#
# /kaggle/working/png_file_dic/18868_1888992659.png
#
# /kaggle/working/png_file_dic/17039_823901608.png
#
# /kaggle/working/png_file_dic/38261_201640183.png
#
# /kaggle/working/png_file_dic/32404_348522566.png
#
# /kaggle/working/png_file_dic/60478_1647820890.png
#
# /kaggle/working/png_file_dic/1791_1008298882.png
#
# /kaggle/working/png_file_dic/51589_138157103.png
#
# /kaggle/working/png_file_dic/62537_486467992.png
#
# /kaggle/working/png_file_dic/25565_1841410360.png
#
# /kaggle/working/png_file_dic/62448_1108352736.png
#
# /kaggle/working/png_file_dic/54795_389606507.png
#
# /kaggle/working/png_file_dic/59622_808346342.png
#
# /kaggle/working/png_file_dic/64018_1923100903.png
#
# /kaggle/working/png_file_dic/10939_1090019410.png
#
# /kaggle/working/png_file_dic/26128_29398905.png
#
# /kaggle/working/png_file_dic/10289_1616844775.png
#
# /kaggle/working/png_file_dic/8294_1744960689.png
#
# /kaggle/working/png_file_dic/5421_1248746586.png
#
# /kaggle/working/png_file_dic/39185_1343535476.png
#
# /kaggle/working/png_file_dic/8570_669955299.png
#
# /kaggle/working/png_file_dic/11298_987308818.png
#
# /kaggle/working/png_file_dic/49682_2126507281.png
#
# /kaggle/working/png_file_dic/26879_1216203659.png
#
# /kaggle/working/png_file_dic/45013_2125539361.png
#
# /kaggle/working/png_file_dic/28008_51821090.png
#
# /kaggle/working/png_file_dic/15756_281984829.png
#
# /kaggle/working/png_file_dic/13103_54005983.png
#
# /kaggle/working/png_file_dic/52106_1385427340.png
#
# /kaggle/working/png_file_dic/48142_752607689.png
#
# /kaggle/working/png_file_dic/10842_97450802.png
#
# /kaggle/working/png_file_dic/29590_1351550814.png
#
# /kaggle/working/png_file_dic/25041_411498993.png
#
# /kaggle/working/png_file_dic/31274_193355365.png
#
# /kaggle/working/png_file_dic/64804_611939005.png
#
# /kaggle/working/png_file_dic/46399_1135399343.png
#
# /kaggle/working/png_file_dic/1424_498012044.png
#
# /kaggle/working/png_file_dic/42225_1097275032.png
#
# /kaggle/working/png_file_dic/11331_27969942.png
#
# /kaggle/working/png_file_dic/42650_847913544.png
#
# /kaggle/working/png_file_dic/20018_1356026210.png
#
# /kaggle/working/png_file_dic/29190_1117489632.png
#
# /kaggle/working/png_file_dic/33534_1202934791.png
#
# ...
#
# /kaggle/working/png_file_dic/21221_448741934.png
#
# /kaggle/working/png_file_dic/53890_775599145.png
#
# /kaggle/working/png_file_dic/46249_1409256383.png
#
# /kaggle/working/png_file_dic/39180_1117936038.png
#
# /kaggle/working/png_file_dic/2248_648057038.png
#
# /kaggle/working/png_file_dic/63402_481567585.png
#
# /kaggle/working/png_file_dic/20180_1707880059.png
#
# /kaggle/working/png_file_dic/54875_293604243.png
#
# /kaggle/working/png_file_dic/55300_794228731.png
#
# /kaggle/working/png_file_dic/43438_803576332.png
#
# /kaggle/working/png_file_dic/19510_457161215.png
#
# /kaggle/working/png_file_dic/65389_372361309.png
#
# /kaggle/working/png_file_dic/2035_1492430786.png
#
# /kaggle/working/png_file_dic/45777_1151820486.png
#
# /kaggle/working/png_file_dic/29000_778230591.png
#
# /kaggle/working/png_file_dic/16862_1975724747.png
#
# /kaggle/working/png_file_dic/36254_1040086815.png
#
# /kaggle/working/png_file_dic/12496_1066955808.png
#
# /kaggle/working/png_file_dic/37193_1701183607.png
#
# /kaggle/working/png_file_dic/53636_1322837831.png
#
# /kaggle/working/png_file_dic/9169_1419274150.png
#
# /kaggle/working/png_file_dic/60537_2001286189.png
#
# /kaggle/working/png_file_dic/51680_787231583.png
#
# /kaggle/working/png_file_dic/2810_1775227547.png
#
# /kaggle/working/png_file_dic/55013_1958519903.png
#
# /kaggle/working/png_file_dic/63352_2134764162.png
#
# /kaggle/working/png_file_dic/38544_1332766566.png
#
# /kaggle/working/png_file_dic/6348_1880439413.png
#
# /kaggle/working/png_file_dic/51418_1030178548.png
#
# /kaggle/working/png_file_dic/59270_2050339868.png
#
# /kaggle/working/png_file_dic/31377_1053754871.png
#
# /kaggle/working/png_file_dic/41508_2126863704.png
#
# /kaggle/working/png_file_dic/49080_656059049.png
#
# /kaggle/working/png_file_dic/6069_399265780.png
#
# /kaggle/working/png_file_dic/18723_2030699807.png
#
# /kaggle/working/png_file_dic/12195_91797551.png
#
# /kaggle/working/png_file_dic/3682_1359841808.png
#
# /kaggle/working/png_file_dic/28368_159022158.png
#
# /kaggle/working/png_file_dic/36748_207616196.png
#
# /kaggle/working/png_file_dic/39571_1605387599.png
#
# /kaggle/working/png_file_dic/16085_1989186100.png
#
# /kaggle/working/png_file_dic/3015_1468516911.png
#
# /kaggle/working/png_file_dic/20523_1676828541.png
#
# /kaggle/working/png_file_dic/1139_1883297363.png
#
# /kaggle/working/png_file_dic/55144_551633472.png
#
# /kaggle/working/png_file_dic/62563_1823575281.png
#
# /kaggle/working/png_file_dic/63300_1394468953.png
#
# /kaggle/working/png_file_dic/2141_652276710.png
#
# /kaggle/working/png_file_dic/23221_1257685849.png
#
# /kaggle/working/png_file_dic/28214_1048720297.png
#
# /kaggle/working/png_file_dic/65181_1193019680.png
#
# /kaggle/working/png_file_dic/15440_1931746489.png
#
# /kaggle/working/png_file_dic/30742_1897622232.png
#
# /kaggle/working/png_file_dic/15951_834918356.png
#
# /kaggle/working/png_file_dic/21431_1267661046.png
#
# /kaggle/working/png_file_dic/42479_737467245.png
#
# /kaggle/working/png_file_dic/8728_1645270533.png
#
# /kaggle/working/png_file_dic/59549_1192817932.png
#
# /kaggle/working/png_file_dic/19689_1836154046.png
#
# /kaggle/working/png_file_dic/4517_1148422709.png
#
# /kaggle/working/png_file_dic/16605_1912714247.png
#
# /kaggle/working/png_file_dic/61139_1595233312.png
#
# /kaggle/working/png_file_dic/16555_1348514082.png
#
# /kaggle/working/png_file_dic/62004_1182317821.png
#
# /kaggle/working/png_file_dic/58020_1185052208.png
#
# /kaggle/working/png_file_dic/16065_753983342.png
#
# /kaggle/working/png_file_dic/48118_1610664547.png
#
# /kaggle/working/png_file_dic/31630_868546085.png
#
# /kaggle/working/png_file_dic/34428_1619130171.png
#
# /kaggle/working/png_file_dic/50328_2130450260.png
#
# /kaggle/working/png_file_dic/57286_1609604771.png
#
# /kaggle/working/png_file_dic/22259_296015259.png
#
# /kaggle/working/png_file_dic/33107_713150095.png
#
# /kaggle/working/png_file_dic/44836_2079956504.png
#
# /kaggle/working/png_file_dic/17808_97569529.png
#
# /kaggle/working/png_file_dic/41369_1721828196.png
#
# /kaggle/working/png_file_dic/57525_550007476.png
#
# /kaggle/working/png_file_dic/18408_472350355.png
#
# /kaggle/working/png_file_dic/15836_460212797.png
#
# /kaggle/working/png_file_dic/11158_743749544.png
#
# /kaggle/working/png_file_dic/4558_130804718.png
#
# /kaggle/working/png_file_dic/41401_1499340598.png
#
# /kaggle/working/png_file_dic/14504_523152135.png
#
# /kaggle/working/png_file_dic/27847_2113232232.png
#
# /kaggle/working/png_file_dic/27550_838715880.png
#
# /kaggle/working/png_file_dic/43753_1572155960.png
#
# /kaggle/working/png_file_dic/44690_1525063031.png
#
# /kaggle/working/png_file_dic/434_1298711753.png
#
# /kaggle/working/png_file_dic/31774_693958311.png
#
# /kaggle/working/png_file_dic/57261_1820241552.png
#
# /kaggle/working/png_file_dic/34341_1871066101.png
#
# /kaggle/working/png_file_dic/31903_266523396.png
#
# /kaggle/working/png_file_dic/42094_1562509737.png
#
# /kaggle/working/png_file_dic/11097_1063696188.png
#
# /kaggle/working/png_file_dic/64262_1119733048.png
#
# /kaggle/working/png_file_dic/24141_1066710235.png
#
# /kaggle/working/png_file_dic/27430_738746305.png
#
# /kaggle/working/png_file_dic/27791_1730926632.png
#
# /kaggle/working/png_file_dic/17220_789692032.png
#
# /kaggle/working/png_file_dic/45222_2105806351.png
#
# /kaggle/working/png_file_dic/13229_992001602.png
#
# /kaggle/working/png_file_dic/13030_1393795902.png
#
# /kaggle/working/png_file_dic/38433_14139342.png
#
# /kaggle/working/png_file_dic/50868_619220747.png
#
# /kaggle/working/png_file_dic/47847_460242872.png
#
# /kaggle/working/png_file_dic/54094_112247144.png
#
# /kaggle/working/png_file_dic/26954_1716417142.png
#
# /kaggle/working/png_file_dic/23607_91238884.png
#
# /kaggle/working/png_file_dic/61375_1753599893.png
#
# /kaggle/working/png_file_dic/5696_755240329.png
#
# /kaggle/working/png_file_dic/7136_1468441364.png
#
# /kaggle/working/png_file_dic/23516_809852505.png
#
# /kaggle/working/png_file_dic/48987_1187729320.png
#
# /kaggle/working/png_file_dic/56992_1323156547.png
#
# /kaggle/working/png_file_dic/58293_608478018.png
#
# /kaggle/working/png_file_dic/41421_1920305979.png
#
# /kaggle/working/png_file_dic/9188_813993554.png
#
# /kaggle/working/png_file_dic/18626_699686579.png
#
# /kaggle/working/png_file_dic/10646_427101910.png
#
# /kaggle/working/png_file_dic/45583_251781397.png
#
# /kaggle/working/png_file_dic/46891_1533464084.png
#
# /kaggle/working/png_file_dic/56892_1305725896.png
#
# /kaggle/working/png_file_dic/27179_947373951.png
#
# /kaggle/working/png_file_dic/31063_1080298490.png
#
# /kaggle/working/png_file_dic/58004_533492333.png
#
# /kaggle/working/png_file_dic/34110_1005679866.png
#
# /kaggle/working/png_file_dic/18831_521894250.png
#
# /kaggle/working/png_file_dic/34028_860228352.png
#
# /kaggle/working/png_file_dic/56435_147861095.png
#
# /kaggle/working/png_file_dic/58164_630395884.png
#
# /kaggle/working/png_file_dic/33843_1412866247.png
#
# /kaggle/working/png_file_dic/57054_782252705.png
#
# /kaggle/working/png_file_dic/17857_955420307.png
#
# /kaggle/working/png_file_dic/24136_449878496.png
#
# /kaggle/working/png_file_dic/56100_2124025779.png
#
# /kaggle/working/png_file_dic/63400_904200217.png
#
# /kaggle/working/png_file_dic/37416_2069951684.png
#
# /kaggle/working/png_file_dic/40943_837889831.png
#
# /kaggle/working/png_file_dic/45044_1715741876.png
#
# /kaggle/working/png_file_dic/7055_140496860.png
#
# /kaggle/working/png_file_dic/21023_1929406731.png
#
# /kaggle/working/png_file_dic/15101_1403277030.png
#
# /kaggle/working/png_file_dic/35288_1805089719.png
#
# /kaggle/working/png_file_dic/19085_1835216806.png
#
# /kaggle/working/png_file_dic/6622_1122306338.png
#
# /kaggle/working/png_file_dic/36521_1408259141.png
#
# /kaggle/working/png_file_dic/53990_1933208098.png
#
# /kaggle/working/png_file_dic/3537_1030119168.png
#
# /kaggle/working/png_file_dic/59549_1979035704.png
#
# /kaggle/working/png_file_dic/23666_1901806958.png
#
# /kaggle/working/png_file_dic/14739_838197193.png
#
# /kaggle/working/png_file_dic/56657_1888054392.png
#
# /kaggle/working/png_file_dic/23068_32218025.png
#
# /kaggle/working/png_file_dic/13366_122659000.png
#
# /kaggle/working/png_file_dic/39957_2087907277.png
#
# /kaggle/working/png_file_dic/6129_1340306660.png
#
# /kaggle/working/png_file_dic/1454_1069912515.png
#
# /kaggle/working/png_file_dic/9513_2028738779.png
#
# /kaggle/working/png_file_dic/17982_2063842635.png
#
# /kaggle/working/png_file_dic/42209_408699140.png
#
# /kaggle/working/png_file_dic/50913_387493002.png
#
# /kaggle/working/png_file_dic/34736_795047176.png
#
# /kaggle/working/png_file_dic/17887_201433517.png
#
# /kaggle/working/png_file_dic/35968_807980912.png
#
# /kaggle/working/png_file_dic/54266_2084124540.png
#
# /kaggle/working/png_file_dic/45945_618149096.png
#
# /kaggle/working/png_file_dic/52334_1817437491.png
#
# /kaggle/working/png_file_dic/58953_2065386986.png
#
# /kaggle/working/png_file_dic/52436_2098806798.png
#
# /kaggle/working/png_file_dic/10208_638273415.png
#
# /kaggle/working/png_file_dic/31652_2010197088.png
#
# /kaggle/working/png_file_dic/12650_1201625991.png
#
# /kaggle/working/png_file_dic/17622_426034550.png
#
# /kaggle/working/png_file_dic/23258_285148032.png
#
# /kaggle/working/png_file_dic/13337_529239460.png
#
# /kaggle/working/png_file_dic/48119_496747963.png
#
# /kaggle/working/png_file_dic/15055_1747037232.png
#
# /kaggle/working/png_file_dic/65346_122077239.png
#
# /kaggle/working/png_file_dic/65088_1949617779.png
#
# /kaggle/working/png_file_dic/1139_1057977754.png
#
# /kaggle/working/png_file_dic/508_2126954428.png
#
# /kaggle/working/png_file_dic/40747_653105152.png
#
# /kaggle/working/png_file_dic/39777_421729443.png
#
# /kaggle/working/png_file_dic/5393_189741615.png
#
# /kaggle/working/png_file_dic/7265_921611377.png
#
# /kaggle/working/png_file_dic/51371_2029456069.png
#
# /kaggle/working/png_file_dic/51341_1687010751.png
#
# /kaggle/working/png_file_dic/42943_1751050085.png
#
# /kaggle/working/png_file_dic/29371_1125720921.png
#
# /kaggle/working/png_file_dic/47935_479725094.png
#
# /kaggle/working/png_file_dic/63813_1986649739.png
#
# /kaggle/working/png_file_dic/48445_2101334501.png
#
# /kaggle/working/png_file_dic/35759_1226165233.png
#
# /kaggle/working/png_file_dic/48985_726237413.png
#
# /kaggle/working/png_file_dic/42500_1716023274.png
#
# /kaggle/working/png_file_dic/23388_2003156477.png
#
# /kaggle/working/png_file_dic/16390_1267884728.png
#
# /kaggle/working/png_file_dic/19853_1686860824.png
#
# /kaggle/working/png_file_dic/36061_205912785.png
#
# /kaggle/working/png_file_dic/17749_132336027.png
#
# /kaggle/working/png_file_dic/4459_251849969.png
#
# /kaggle/working/png_file_dic/14580_1661735781.png
#
# /kaggle/working/png_file_dic/57173_835315972.png
#
# /kaggle/working/png_file_dic/28367_648431411.png
#
# /kaggle/working/png_file_dic/9559_790325351.png
#
# /kaggle/working/png_file_dic/11943_554413986.png
#
# /kaggle/working/png_file_dic/47011_1272714911.png
#
# /kaggle/working/png_file_dic/23604_604905139.png
#
# /kaggle/working/png_file_dic/7539_1386803329.png
#
# /kaggle/working/png_file_dic/52481_2098899044.png
#
# /kaggle/working/png_file_dic/39896_527923549.png
#
# /kaggle/working/png_file_dic/43753_43888885.png
#
# /kaggle/working/png_file_dic/30203_1244341407.png
#
# /kaggle/working/png_file_dic/25473_2007072457.png
#
# /kaggle/working/png_file_dic/4787_1262299760.png
#
# /kaggle/working/png_file_dic/57881_1705155444.png
#
# /kaggle/working/png_file_dic/37748_1393152470.png
#
# /kaggle/working/png_file_dic/57714_252907034.png
#
# /kaggle/working/png_file_dic/41421_1142863320.png
#
# /kaggle/working/png_file_dic/54245_1344487209.png
#
# /kaggle/working/png_file_dic/10741_1616696471.png
#
# /kaggle/working/png_file_dic/46011_2120333524.png
#
# /kaggle/working/png_file_dic/2478_2103697614.png
#
# /kaggle/working/png_file_dic/43864_422053908.png
#
# /kaggle/working/png_file_dic/53914_239791638.png
#
# /kaggle/working/png_file_dic/9949_809479419.png
#
# /kaggle/working/png_file_dic/53918_1020139496.png
#
# /kaggle/working/png_file_dic/6191_1214353628.png
#
# /kaggle/working/png_file_dic/37931_1597761099.png
#
# /kaggle/working/png_file_dic/43755_1017257794.png
#
# /kaggle/working/png_file_dic/26012_1266860965.png
#
# /kaggle/working/png_file_dic/11934_745482262.png
#
# /kaggle/working/png_file_dic/44633_761549134.png
#
# /kaggle/working/png_file_dic/43544_875402319.png
#
# /kaggle/working/png_file_dic/3575_8076172.png
#
# /kaggle/working/png_file_dic/53959_1055578759.png
#
# /kaggle/working/png_file_dic/54338_861293928.png
#
# /kaggle/working/png_file_dic/39320_913477151.png
#
# /kaggle/working/png_file_dic/5766_648982229.png
#
# /kaggle/working/png_file_dic/25207_1648781528.png
#
# /kaggle/working/png_file_dic/10097_1957744616.png
#
# /kaggle/working/png_file_dic/2302_1361529898.png
#
# /kaggle/working/png_file_dic/31670_1707561236.png
#
# /kaggle/working/png_file_dic/44759_234893219.png
#
# /kaggle/working/png_file_dic/7065_549915661.png
#
# /kaggle/working/png_file_dic/63112_1306491932.png
#
# /kaggle/working/png_file_dic/62248_1337158484.png
#
# /kaggle/working/png_file_dic/36472_1960885464.png
#
# /kaggle/working/png_file_dic/3383_26698955.png
#
# /kaggle/working/png_file_dic/50135_1855048119.png
#
# /kaggle/working/png_file_dic/21780_1846320694.png
#
# /kaggle/working/png_file_dic/65431_2048037268.png
#
# /kaggle/working/png_file_dic/27681_942937022.png
#
# /kaggle/working/png_file_dic/9297_1335365954.png
#
# /kaggle/working/png_file_dic/39252_1639041503.png
#
# /kaggle/working/png_file_dic/3544_1826143266.png
#
# /kaggle/working/png_file_dic/43955_640739937.png
#
# /kaggle/working/png_file_dic/9307_1827378807.png
#
# /kaggle/working/png_file_dic/2180_980414212.png
#
# /kaggle/working/png_file_dic/8926_2062394508.png
#
# /kaggle/working/png_file_dic/50382_681640004.png
#
# /kaggle/working/png_file_dic/8825_1985915887.png
#
# /kaggle/working/png_file_dic/58960_2073446133.png
#
# /kaggle/working/png_file_dic/51627_8017397.png
#
# /kaggle/working/png_file_dic/4996_287914037.png
#
# /kaggle/working/png_file_dic/1318_993242356.png
#
# /kaggle/working/png_file_dic/22243_306563249.png
#
# /kaggle/working/png_file_dic/39539_111444846.png
#
# /kaggle/working/png_file_dic/60752_1005853922.png
#
# /kaggle/working/png_file_dic/28327_2110455754.png
#
# /kaggle/working/png_file_dic/16703_304734585.png
#
# /kaggle/working/png_file_dic/29304_1434352722.png
#
# /kaggle/working/png_file_dic/41948_2127534551.png
#
# /kaggle/working/png_file_dic/22376_392798912.png
#
# /kaggle/working/png_file_dic/20264_1415827741.png
#
# /kaggle/working/png_file_dic/62100_953857949.png
#
# /kaggle/working/png_file_dic/44141_122300016.png
#
# /kaggle/working/png_file_dic/59086_1679684757.png
#
# /kaggle/working/png_file_dic/129_460565604.png
#
# /kaggle/working/png_file_dic/14091_471058643.png
#
# /kaggle/working/png_file_dic/19960_559538218.png
#
# /kaggle/working/png_file_dic/308_560252538.png
#
# /kaggle/working/png_file_dic/40509_434133494.png
#
# /kaggle/working/png_file_dic/45274_248194422.png
#
# /kaggle/working/png_file_dic/2488_1408995603.png
#
# /kaggle/working/png_file_dic/46996_168550657.png
#
# /kaggle/working/png_file_dic/26356_946575196.png
#
# /kaggle/working/png_file_dic/1458_1760846031.png
#
# /kaggle/working/png_file_dic/49239_1016462923.png
#
# /kaggle/working/png_file_dic/6724_1964988176.png
#
# /kaggle/working/png_file_dic/20317_950869288.png
#
# /kaggle/working/png_file_dic/1983_1966406947.png
#
# /kaggle/working/png_file_dic/49166_1727001667.png
#
# /kaggle/working/png_file_dic/27026_557376738.png
#
# /kaggle/working/png_file_dic/54704_590878766.png
#
# /kaggle/working/png_file_dic/42434_1156275543.png
#
# /kaggle/working/png_file_dic/17066_109806777.png
#
# /kaggle/working/png_file_dic/38493_145885856.png
#
# /kaggle/working/png_file_dic/25162_214139325.png
#
# /kaggle/working/png_file_dic/38355_1667643155.png
#
# /kaggle/working/png_file_dic/61011_598547127.png
#
# /kaggle/working/png_file_dic/49427_1744349338.png
#
# /kaggle/working/png_file_dic/46675_281052379.png
#
# /kaggle/working/png_file_dic/57739_1734653062.png
#
# /kaggle/working/png_file_dic/25266_894715323.png
#
# /kaggle/working/png_file_dic/38131_1814546332.png
#
# /kaggle/working/png_file_dic/43805_735678527.png
#
# /kaggle/working/png_file_dic/25823_1020017303.png
#
# /kaggle/working/png_file_dic/50336_753309024.png
#
# /kaggle/working/png_file_dic/46760_794519278.png
#
# /kaggle/working/png_file_dic/7054_1712181451.png
#
# /kaggle/working/png_file_dic/37748_181361234.png
#
# /kaggle/working/png_file_dic/62139_1076016131.png
#
# /kaggle/working/png_file_dic/31121_117458566.png
#
# /kaggle/working/png_file_dic/55376_1920151242.png
#
# /kaggle/working/png_file_dic/8686_742704507.png
#
# /kaggle/working/png_file_dic/28056_1821605755.png
